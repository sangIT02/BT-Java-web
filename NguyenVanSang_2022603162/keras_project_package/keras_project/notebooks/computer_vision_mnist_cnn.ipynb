# %% [markdown]
# # Computer Vision – MNIST CNN

# %% [markdown]
# # 🧪 Computer Vision – MNIST CNN (Keras)

# %% [markdown]
# ## Hướng dẫn: Runtime → GPU; chạy cell từ trên xuống; chụp đồ thị loss/accuracy

# %%
# !pip install -U tensorflow keras

# %%
import tensorflow as tf, numpy as np, matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = (x_train/255.0).astype('float32')[..., None]
x_test = (x_test/255.0).astype('float32')[..., None]

model = keras.Sequential([
    layers.Conv2D(32, 3, activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.1)

print('Test acc:', model.evaluate(x_test, y_test, verbose=0)[1])
plt.figure(); plt.plot(hist.history['accuracy'], label='acc'); plt.plot(hist.history['val_accuracy'], label='val_acc'); plt.legend(); plt.title('Accuracy'); plt.xlabel('epoch'); plt.show()
pred = model.predict(x_test[:9])
plt.figure(figsize=(6,6))
for i in range(9):
    plt.subplot(3,3,i+1); plt.imshow(x_test[i].squeeze(), cmap='gray'); plt.title(np.argmax(pred[i])); plt.axis('off')
plt.tight_layout(); plt.show()
